# %% [markdown]
# # Exploring Pandas with some WMIC output
#
# For this example, lets pull some current service data from our system and see how we can explore it with Pandas. Of course, for hunting or assessment, we would either have multiple instances of this output for one machine over some period of time, or we could compare the output from multiple machines.
#
# To get the data, I just ran a `wmic SERVICE LIST BRIEF` as Admin on my personal computer. Below is the output.

# %%
filename = "C:\services.txt"

with open(filename) as file:
    for line in file:
        print(line.strip())
# Out:
# ÿþExitCode  Name                                                    ProcessId  StartMode  State    Status
#
# 1077      AJRouter                                                0          Manual     Stopped  OK
#
# 1077      ALG                                                     0          Manual     Stopped  OK
#
# 1077      AppIDSvc                                                0          Manual     Stopped  OK
#
# 0         Appinfo                                                 10364      Manual     Running  OK
#
# 1077      AppReadiness                                            0          Manual     Stopped  OK
#
# 0         AppXSvc                                                 10060      Manual     Running  OK
#
# 1077      aspnet_state                                            0          Manual     Stopped  OK
#
# 0         AudioEndpointBuilder                                    3292       Auto       Running  OK
#
# 0         Audiosrv                                                3480       Auto       Running  OK
#
# 1077      autotimesvc                                             0          Manual     Stopped  OK
#
# 1077      AxInstSV                                                0          Manual     Stopped  OK
#
# 0         BDESVC                                                  0          Manual     Stopped  OK
#
# 0         BFE                                                     3076       Auto       Running  OK
#
# 0         BITS                                                    812        Auto       Running  OK
#
# 0         BrokerInfrastructure                                    880        Auto       Running  OK
#
# 1077      Browser                                                 0          Manual     Stopped  OK
#
# 0         BTAGService                                             1436       Manual     Running  OK
#
# 0         BthAvctpSvc                                             1484       Manual     Running  OK
#
# 0         bthserv                                                 1556       Manual     Running  OK
#
# 0         camsvc                                                  2568       Manual     Running  OK
#
# 0         CDPSvc                                                  6280       Auto       Running  OK
#
# 0         CertPropSvc                                             1756       Manual     Running  OK
#
# 0         ClickToRunSvc                                           4132       Auto       Running  OK
#
# 0         ClipSVC                                                 0          Manual     Stopped  OK
#
# 0         com.docker.service                                      4844       Auto       Running  OK
#
# 1077      COMSysApp                                               0          Manual     Stopped  OK
#
# 0         CoreMessagingRegistrar                                  1848       Auto       Running  OK
#
# 0         cplspcon                                                4104       Auto       Running  OK
#
# 0         CryptSvc                                                2868       Auto       Running  OK
#
# 0         DcomLaunch                                              880        Auto       Running  OK
#
# 1077      defragsvc                                               0          Manual     Stopped  OK
#
# 0         DeviceAssociationService                                2432       Manual     Running  OK
#
# 1077      DeviceInstall                                           0          Manual     Stopped  OK
#
# 1077      DevQueryBroker                                          0          Manual     Stopped  OK
#
# 0         Dhcp                                                    2084       Auto       Running  OK
#
# 1077      diagnosticshub.standardcollector.service                0          Manual     Stopped  OK
#
# 1077      diagsvc                                                 0          Manual     Stopped  OK
#
# 0         DiagTrack                                               4112       Auto       Running  OK
#
# 0         DispBrokerDesktopSvc                                    2336       Auto       Running  OK
#
# 0         DisplayEnhancementService                               1820       Manual     Running  OK
#
# 1077      DmEnrollmentSvc                                         0          Manual     Stopped  OK
#
# 1077      dmwappushservice                                        0          Manual     Stopped  OK
#
# 0         Dnscache                                                3604       Auto       Running  OK
#
# 0         DoSvc                                                   11000      Auto       Running  OK
#
# 1077      dot3svc                                                 0          Manual     Stopped  OK
#
# 0         DPS                                                     4124       Auto       Running  OK
#
# 0         DsmSvc                                                  0          Manual     Stopped  OK
#
# 1077      DsSvc                                                   0          Manual     Stopped  OK
#
# 0         DusmSvc                                                 3616       Auto       Running  OK
#
# 1077      Eaphost                                                 0          Manual     Stopped  OK
#
# 0         edgeupdate                                              0          Auto       Stopped  OK
#
# 1077      edgeupdatem                                             0          Manual     Stopped  OK
#
# 1077      EFS                                                     0          Manual     Stopped  OK
#
# 1077      embeddedmode                                            0          Manual     Stopped  OK
#
# 1077      EntAppSvc                                               0          Manual     Stopped  OK
#
# 0         esifsvc                                                 4244       Auto       Running  OK
#
# 0         EventLog                                                1712       Auto       Running  OK
#
# 0         EventSystem                                             1972       Auto       Running  OK
#
# 1077      Fax                                                     0          Manual     Stopped  OK
#
# 1077      fdPHost                                                 0          Manual     Stopped  OK
#
# 1077      FDResPub                                                0          Manual     Stopped  OK
#
# 1077      fhsvc                                                   0          Manual     Stopped  OK
#
# 0         FontCache                                               3312       Auto       Running  OK
#
# 0         FrameServer                                             0          Manual     Stopped  OK
#
# 1077      GoogleChromeElevationService                            0          Manual     Stopped  OK
#
# 0         gpsvc                                                   0          Auto       Stopped  OK
#
# 1077      GraphicsPerfSvc                                         0          Manual     Stopped  OK
#
# 0         gupdate                                                 0          Auto       Stopped  OK
#
# 1077      gupdatem                                                0          Manual     Stopped  OK
#
# 1077      HfcDisableService                                       0          Disabled   Stopped  OK
#
# 1077      hidserv                                                 0          Manual     Stopped  OK
#
# 0         hns                                                     3036       Manual     Running  OK
#
# 0         HPAppHelperCap                                          2676       Auto       Running  OK
#
# 0         HPNetworkCap                                            2696       Auto       Running  OK
#
# 0         HPSysInfoCap                                            2688       Auto       Running  OK
#
# 0         HpTouchpointAnalyticsService                            2712       Auto       Running  OK
#
# 0         HvHost                                                  1424       Manual     Running  OK
#
# 1077      iaStorAfsService                                        0          Manual     Stopped  OK
#
# 1077      icssvc                                                  0          Manual     Stopped  OK
#
# 0         igccservice                                             4192       Auto       Running  OK
#
# 0         igfxCUIService2.0.0.0                                   2300       Auto       Running  OK
#
# 1077      IKEEXT                                                  0          Manual     Stopped  OK
#
# 0         InstallService                                          11428      Manual     Running  OK
#
# 1077      Intel(R) Capability Licensing Service TCP IP Interface  0          Manual     Stopped  OK
#
# 0         Intel(R) TPM Provisioning Service                       0          Auto       Stopped  OK
#
# 0         iphlpsvc                                                4228       Auto       Running  OK
#
# 1077      IpxlatCfgSvc                                            0          Manual     Stopped  OK
#
# 0         jhi_service                                             4476       Auto       Running  OK
#
# 0         KeyIso                                                  948        Manual     Running  OK
#
# 1077      KtmRm                                                   0          Manual     Stopped  OK
#
# 0         LanmanServer                                            4144       Auto       Running  OK
#
# 0         LanmanWorkstation                                       3092       Auto       Running  OK
#
# 0         lfsvc                                                   7304       Manual     Running  OK
#
# 0         LicenseManager                                          5872       Manual     Running  OK
#
# 1077      lltdsvc                                                 0          Manual     Stopped  OK
#
# 0         lmhosts                                                 10876      Manual     Running  OK
#
# 0         LMS                                                     4312       Auto       Running  OK
#
# 0         LSM                                                     1208       Auto       Running  OK
#
# 1077      LxpSvc                                                  0          Manual     Stopped  OK
#
# 1077      LxssManager                                             0          Manual     Stopped  OK
#
# 0         MapsBroker                                              0          Auto       Stopped  OK
#
# 1077      MicrosoftEdgeElevationService                           0          Manual     Stopped  OK
#
# 1077      MixedRealityOpenXRSvc                                   0          Manual     Stopped  OK
#
# 0         mpssvc                                                  3076       Auto       Running  OK
#
# 1077      MSDTC                                                   0          Manual     Stopped  OK
#
# 1077      MSiSCSI                                                 0          Manual     Stopped  OK
#
# 1077      msiserver                                               0          Manual     Stopped  OK
#
# 1077      NaturalAuthentication                                   0          Manual     Stopped  OK
#
# 1077      NcaSvc                                                  0          Manual     Stopped  OK
#
# 0         NcbService                                              1584       Manual     Running  OK
#
# 1077      NcdAutoSetup                                            0          Manual     Stopped  OK
#
# 1077      Netlogon                                                0          Manual     Stopped  OK
#
# 1077      Netman                                                  0          Manual     Stopped  OK
#
# 0         netprofm                                                2808       Manual     Running  OK
#
# 0         NetSetupSvc                                             0          Manual     Stopped  OK
#
# 1077      NetTcpPortSharing                                       0          Disabled   Stopped  OK
#
# 0         NgcCtnrSvc                                              2308       Manual     Running  OK
#
# 0         NgcSvc                                                  5808       Manual     Running  OK
#
# 0         NlaSvc                                                  2384       Auto       Running  OK
#
# 0         nsi                                                     2036       Auto       Running  OK
#
# 0         nvagent                                                 2460       Manual     Running  OK
#
# 1077      ose64                                                   0          Manual     Stopped  OK
#
# 1077      p2pimsvc                                                0          Manual     Stopped  OK
#
# 1077      p2psvc                                                  0          Manual     Stopped  OK
#
# 0         PcaSvc                                                  5392       Manual     Running  OK
#
# 1077      perceptionsimulation                                    0          Manual     Stopped  OK
#
# 1077      PerfHost                                                0          Manual     Stopped  OK
#
# 1077      PhoneSvc                                                0          Manual     Stopped  OK
#
# 1077      pla                                                     0          Manual     Stopped  OK
#
# 0         PlugPlay                                                588        Manual     Running  OK
#
# 1077      PNRPAutoReg                                             0          Manual     Stopped  OK
#
# 1077      PNRPsvc                                                 0          Manual     Stopped  OK
#
# 1077      PolicyAgent                                             0          Manual     Stopped  OK
#
# 0         Power                                                   880        Auto       Running  OK
#
# 1077      PrintNotify                                             0          Manual     Stopped  OK
#
# 0         ProfSvc                                                 1944       Auto       Running  OK
#
# 0         PushToInstall                                           0          Manual     Stopped  OK
#
# 0         QWAVE                                                   11600      Manual     Running  OK
#
# 1077      RasAuto                                                 0          Manual     Stopped  OK
#
# 0         RasMan                                                  5056       Auto       Running  OK
#
# 1077      RemoteAccess                                            0          Disabled   Stopped  OK
#
# 1077      RemoteRegistry                                          0          Disabled   Stopped  OK
#
# 1077      RetailDemo                                              0          Manual     Stopped  OK
#
# 0         RmSvc                                                   5464       Manual     Running  OK
#
# 0         RpcEptMapper                                            1152       Auto       Running  OK
#
# 1077      RpcLocator                                              0          Manual     Stopped  OK
#
# 0         RpcSs                                                   1152       Auto       Running  OK
#
# 0         RstMwService                                            4396       Auto       Running  OK
#
# 0         RtkAudioUniversalService                                4404       Auto       Running  OK
#
# 0         RtkBtManServ                                            4420       Auto       Running  OK
#
# 0         SamSs                                                   948        Auto       Running  OK
#
# 0         SCardSvr                                                1544       Manual     Running  OK
#
# 0         ScDeviceEnum                                            0          Manual     Stopped  OK
#
# 0         Schedule                                                1728       Auto       Running  OK
#
# 1077      SCPolicySvc                                             0          Manual     Stopped  OK
#
# 1077      SDRSVC                                                  0          Manual     Stopped  OK
#
# 1077      seclogon                                                0          Manual     Stopped  OK
#
# 0         SECOMNService                                           4412       Auto       Running  OK
#
# 0         SecurityHealthService                                   10052      Manual     Running  OK
#
# 1077      SEMgrSvc                                                0          Manual     Stopped  OK
#
# 0         SENS                                                    2148       Auto       Running  OK
#
# 1077      SensorDataService                                       0          Manual     Stopped  OK
#
# 1077      SensorService                                           0          Manual     Stopped  OK
#
# 1077      SensrSvc                                                0          Manual     Stopped  OK
#
# 1077      SessionEnv                                              0          Manual     Stopped  OK
#
# 0         SgrmBroker                                              11548      Auto       Running  OK
#
# 0         SharedAccess                                            3364       Manual     Running  OK
#
# 1077      SharedRealitySvc                                        0          Manual     Stopped  OK
#
# 0         ShellHWDetection                                        3948       Auto       Running  OK
#
# 1077      shpamsvc                                                0          Disabled   Stopped  OK
#
# 1077      smphost                                                 0          Manual     Stopped  OK
#
# 1077      SmsRouter                                               0          Manual     Stopped  OK
#
# 1077      SNMPTRAP                                                0          Manual     Stopped  OK
#
# 1077      spectrum                                                0          Manual     Stopped  OK
#
# 0         Spooler                                                 4040       Auto       Running  OK
#
# 0         sppsvc                                                  0          Auto       Stopped  OK
#
# 0         SSDPSRV                                                 1164       Manual     Running  OK
#
# 1077      ssh-agent                                               0          Disabled   Stopped  OK
#
# 0         SstpSvc                                                 4388       Manual     Running  OK
#
# 0         StateRepository                                         2548       Manual     Running  OK
#
# 1077      stisvc                                                  0          Manual     Stopped  OK
#
# 0         StorSvc                                                 12196      Auto       Running  OK
#
# 1077      svsvc                                                   0          Manual     Stopped  OK
#
# 1077      swprv                                                   0          Manual     Stopped  OK
#
# 0         SynTPEnhService                                         3196       Auto       Running  OK
#
# 0         SysMain                                                 3232       Auto       Running  OK
#
# 0         SystemEventsBroker                                      880        Auto       Running  OK
#
# 0         TabletInputService                                      7028       Manual     Running  OK
#
# 1077      TapiSrv                                                 0          Manual     Stopped  OK
#
# 1077      TermService                                             0          Manual     Stopped  OK
#
# 0         Themes                                                  3244       Auto       Running  OK
#
# 1077      TieringEngineService                                    0          Manual     Stopped  OK
#
# 0         TimeBrokerSvc                                           1600       Manual     Running  OK
#
# 0         TokenBroker                                             6980       Manual     Running  OK
#
# 0         TrkWks                                                  4568       Auto       Running  OK
#
# 1077      TroubleshootingSvc                                      0          Manual     Stopped  OK
#
# 0         TrustedInstaller                                        0          Manual     Stopped  OK
#
# 1077      tzautoupdate                                            0          Disabled   Stopped  OK
#
# 1077      UmRdpService                                            0          Manual     Stopped  OK
#
# 1077      upnphost                                                0          Manual     Stopped  OK
#
# 0         UserManager                                             2076       Auto       Running  OK
#
# 0         UsoSvc                                                  3692       Auto       Running  OK
#
# 1077      VacSvc                                                  0          Manual     Stopped  OK
#
# 0         VaultSvc                                                948        Manual     Running  OK
#
# 1077      vds                                                     0          Manual     Stopped  OK
#
# 1077      vmcompute                                               0          Manual     Stopped  OK
#
# 1077      vmicguestinterface                                      0          Manual     Stopped  OK
#
# 1077      vmicheartbeat                                           0          Manual     Stopped  OK
#
# 1077      vmickvpexchange                                         0          Manual     Stopped  OK
#
# 1077      vmicrdv                                                 0          Manual     Stopped  OK
#
# 1077      vmicshutdown                                            0          Manual     Stopped  OK
#
# 1077      vmictimesync                                            0          Manual     Stopped  OK
#
# 1077      vmicvmsession                                           0          Manual     Stopped  OK
#
# 1077      vmicvss                                                 0          Manual     Stopped  OK
#
# 1077      VSS                                                     0          Manual     Stopped  OK
#
# 1077      W32Time                                                 0          Manual     Stopped  OK
#
# 0         WaaSMedicSvc                                            0          Manual     Stopped  OK
#
# 1077      WalletService                                           0          Manual     Stopped  OK
#
# 1077      WarpJITSvc                                              0          Manual     Stopped  OK
#
# 1077      wbengine                                                0          Manual     Stopped  OK
#
# 1077      WbioSrvc                                                0          Manual     Stopped  OK
#
# 0         Wcmsvc                                                  3644       Auto       Running  OK
#
# 1077      wcncsvc                                                 0          Manual     Stopped  OK
#
# 0         WdiServiceHost                                          4544       Manual     Running  OK
#
# 0         WdiSystemHost                                           10612      Manual     Running  OK
#
# 0         WdNisSvc                                                4252       Manual     Running  OK
#
# 1077      WebClient                                               0          Manual     Stopped  OK
#
# 1077      Wecsvc                                                  0          Manual     Stopped  OK
#
# 1077      WEPHOSTSVC                                              0          Manual     Stopped  OK
#
# 1077      wercplsupport                                           0          Manual     Stopped  OK
#
# 1077      WerSvc                                                  0          Manual     Stopped  OK
#
# 1077      WFDSConMgrSvc                                           0          Manual     Stopped  OK
#
# 1077      WiaRpc                                                  0          Manual     Stopped  OK
#
# 0         WinDefend                                               4436       Auto       Running  OK
#
# 0         WinHttpAutoProxySvc                                     3792       Manual     Running  OK
#
# 0         Winmgmt                                                 3096       Auto       Running  OK
#
# 1077      WinRM                                                   0          Manual     Stopped  OK
#
# 1077      wisvc                                                   0          Manual     Stopped  OK
#
# 0         WlanSvc                                                 3880       Auto       Running  OK
#
# 0         wlidsvc                                                 5888       Manual     Running  OK
#
# 1077      wlpasvc                                                 0          Manual     Stopped  OK
#
# 1077      WManSvc                                                 0          Manual     Stopped  OK
#
# 1077      wmiApSrv                                                0          Manual     Stopped  OK
#
# 1077      WMPNetworkSvc                                           0          Manual     Stopped  OK
#
# 1077      workfolderssvc                                          0          Manual     Stopped  OK
#
# 1077      WpcMonSvc                                               0          Manual     Stopped  OK
#
# 0         WPDBusEnum                                              0          Manual     Stopped  OK
#
# 0         WpnService                                              4484       Auto       Running  OK
#
# 0         wscsvc                                                  5084       Auto       Running  OK
#
# 0         WSearch                                                 7440       Auto       Running  OK
#
# 0         wuauserv                                                0          Manual     Stopped  OK
#
# 1077      WwanSvc                                                 0          Manual     Stopped  OK
#
# 0         XblAuthManager                                          0          Manual     Stopped  OK
#
# 1077      XblGameSave                                             0          Manual     Stopped  OK
#
# 1077      XboxGipSvc                                              0          Manual     Stopped  OK
#
# 1077      XboxNetApiSvc                                           0          Manual     Stopped  OK
#
# 1077      AarSvc_953d5                                            0          Manual     Stopped  OK
#
# 1077      BcastDVRUserService_953d5                               0          Manual     Stopped  OK
#
# 0         BluetoothUserService_953d5                              6728       Manual     Running  OK
#
# 1077      CaptureService_953d5                                    0          Manual     Stopped  OK
#
# 0         cbdhsvc_953d5                                           6888       Manual     Running  OK
#
# 0         CDPUserSvc_953d5                                        6724       Auto       Running  OK
#
# 1077      ConsentUxUserSvc_953d5                                  0          Manual     Stopped  OK
#
# 1077      CredentialEnrollmentManagerUserSvc_953d5                0          Manual     Stopped  OK
#
# 1077      DeviceAssociationBrokerSvc_953d5                        0          Manual     Stopped  OK
#
# 1077      DevicePickerUserSvc_953d5                               0          Manual     Stopped  OK
#
# 1077      DevicesFlowUserSvc_953d5                                0          Manual     Stopped  OK
#
# 1077      LxssManagerUser_953d5                                   0          Manual     Stopped  OK
#
# 1077      MessagingService_953d5                                  0          Manual     Stopped  OK
#
# 0         OneSyncSvc_953d5                                        8532       Auto       Running  OK
#
# 1077      PimIndexMaintenanceSvc_953d5                            0          Manual     Stopped  OK
#
# 1077      PrintWorkflowUserSvc_953d5                              0          Manual     Stopped  OK
#
# 1077      UdkUserSvc_953d5                                        0          Manual     Stopped  OK
#
# 1077      UnistoreSvc_953d5                                       0          Manual     Stopped  OK
#
# 1077      UserDataSvc_953d5                                       0          Manual     Stopped  OK
#
# 0         WpnUserService_953d5                                    6784       Auto       Running  OK

# %% [markdown]
# Of course, you could use a remote wmic command or PowerShell to get a similar table from a remote machine or, for the purpose of this exploration, the local machine (if Windows).

# %%
import os

services = os.popen("wmic SERVICE LIST BRIEF").read().split('\n\n')
services
# Out:
# ['ExitCode  Name                                                    ProcessId  StartMode  State    Status   ',
#  '1077      AJRouter                                                0          Manual     Stopped  OK       ',
#  '1077      ALG                                                     0          Manual     Stopped  OK       ',
#  '1077      AppIDSvc                                                0          Manual     Stopped  OK       ',
#  '0         Appinfo                                                 10364      Manual     Running  OK       ',
#  '1077      AppReadiness                                            0          Manual     Stopped  OK       ',
#  '0         AppXSvc                                                 13228      Manual     Running  OK       ',
#  '1077      aspnet_state                                            0          Manual     Stopped  OK       ',
#  '0         AudioEndpointBuilder                                    3292       Auto       Running  OK       ',
#  '0         Audiosrv                                                3480       Auto       Running  OK       ',
#  '1077      autotimesvc                                             0          Manual     Stopped  OK       ',
#  '1077      AxInstSV                                                0          Manual     Stopped  OK       ',
#  '0         BDESVC                                                  0          Manual     Stopped  OK       ',
#  '0         BFE                                                     3076       Auto       Running  OK       ',
#  '0         BITS                                                    812        Auto       Running  OK       ',
#  '0         BrokerInfrastructure                                    880        Auto       Running  OK       ',
#  '1077      Browser                                                 0          Manual     Stopped  OK       ',
#  '0         BTAGService                                             1436       Manual     Running  OK       ',
#  '0         BthAvctpSvc                                             1484       Manual     Running  OK       ',
#  '0         bthserv                                                 1556       Manual     Running  OK       ',
#  '0         camsvc                                                  2568       Manual     Running  OK       ',
#  '0         CDPSvc                                                  6280       Auto       Running  OK       ',
#  '0         CertPropSvc                                             1756       Manual     Running  OK       ',
#  '0         ClickToRunSvc                                           4132       Auto       Running  OK       ',
#  '0         ClipSVC                                                 0          Manual     Stopped  OK       ',
#  '0         com.docker.service                                      4844       Auto       Running  OK       ',
#  '1077      COMSysApp                                               0          Manual     Stopped  OK       ',
#  '0         CoreMessagingRegistrar                                  1848       Auto       Running  OK       ',
#  '0         cplspcon                                                4104       Auto       Running  OK       ',
#  '0         CryptSvc                                                2868       Auto       Running  OK       ',
#  '0         DcomLaunch                                              880        Auto       Running  OK       ',
#  '0         defragsvc                                               0          Manual     Stopped  OK       ',
#  '0         DeviceAssociationService                                2432       Manual     Running  OK       ',
#  '1077      DeviceInstall                                           0          Manual     Stopped  OK       ',
#  '0         DevQueryBroker                                          8096       Manual     Running  OK       ',
#  '0         Dhcp                                                    2084       Auto       Running  OK       ',
#  '1077      diagnosticshub.standardcollector.service                0          Manual     Stopped  OK       ',
#  '1077      diagsvc                                                 0          Manual     Stopped  OK       ',
#  '0         DiagTrack                                               4112       Auto       Running  OK       ',
#  '0         DispBrokerDesktopSvc                                    2336       Auto       Running  OK       ',
#  '0         DisplayEnhancementService                               1820       Manual     Running  OK       ',
#  '1077      DmEnrollmentSvc                                         0          Manual     Stopped  OK       ',
#  '0         dmwappushservice                                        0          Manual     Stopped  OK       ',
#  '0         Dnscache                                                3604       Auto       Running  OK       ',
#  '0         DoSvc                                                   11000      Auto       Running  OK       ',
#  '1077      dot3svc                                                 0          Manual     Stopped  OK       ',
#  '0         DPS                                                     4124       Auto       Running  OK       ',
#  '0         DsmSvc                                                  0          Manual     Stopped  OK       ',
#  '0         DsSvc                                                   7196       Manual     Running  OK       ',
#  '0         DusmSvc                                                 3616       Auto       Running  OK       ',
#  '1077      Eaphost                                                 0          Manual     Stopped  OK       ',
#  '0         edgeupdate                                              0          Auto       Stopped  OK       ',
#  '1077      edgeupdatem                                             0          Manual     Stopped  OK       ',
#  '1077      EFS                                                     0          Manual     Stopped  OK       ',
#  '1077      embeddedmode                                            0          Manual     Stopped  OK       ',
#  '1077      EntAppSvc                                               0          Manual     Stopped  OK       ',
#  '0         esifsvc                                                 4244       Auto       Running  OK       ',
#  '0         EventLog                                                1712       Auto       Running  OK       ',
#  '0         EventSystem                                             1972       Auto       Running  OK       ',
#  '1077      Fax                                                     0          Manual     Stopped  OK       ',
#  '1077      fdPHost                                                 0          Manual     Stopped  OK       ',
#  '1077      FDResPub                                                0          Manual     Stopped  OK       ',
#  '1077      fhsvc                                                   0          Manual     Stopped  OK       ',
#  '0         FontCache                                               3312       Auto       Running  OK       ',
#  '0         FrameServer                                             0          Manual     Stopped  OK       ',
#  '1077      GoogleChromeElevationService                            0          Manual     Stopped  OK       ',
#  '0         gpsvc                                                   0          Auto       Stopped  OK       ',
#  '1077      GraphicsPerfSvc                                         0          Manual     Stopped  OK       ',
#  '0         gupdate                                                 0          Auto       Stopped  OK       ',
#  '1077      gupdatem                                                0          Manual     Stopped  OK       ',
#  '1077      HfcDisableService                                       0          Disabled   Stopped  OK       ',
#  '1077      hidserv                                                 0          Manual     Stopped  OK       ',
#  '0         hns                                                     3036       Manual     Running  OK       ',
#  '0         HPAppHelperCap                                          2676       Auto       Running  OK       ',
#  '0         HPNetworkCap                                            2696       Auto       Running  OK       ',
#  '0         HPSysInfoCap                                            2688       Auto       Running  OK       ',
#  '0         HpTouchpointAnalyticsService                            2712       Auto       Running  OK       ',
#  '0         HvHost                                                  1424       Manual     Running  OK       ',
#  '1077      iaStorAfsService                                        0          Manual     Stopped  OK       ',
#  '1077      icssvc                                                  0          Manual     Stopped  OK       ',
#  '0         igccservice                                             4192       Auto       Running  OK       ',
#  '0         igfxCUIService2.0.0.0                                   2300       Auto       Running  OK       ',
#  '1077      IKEEXT                                                  0          Manual     Stopped  OK       ',
#  '0         InstallService                                          11428      Manual     Running  OK       ',
#  '1077      Intel(R) Capability Licensing Service TCP IP Interface  0          Manual     Stopped  OK       ',
#  '0         Intel(R) TPM Provisioning Service                       0          Auto       Stopped  OK       ',
#  '0         iphlpsvc                                                4228       Auto       Running  OK       ',
#  '1077      IpxlatCfgSvc                                            0          Manual     Stopped  OK       ',
#  '0         jhi_service                                             4476       Auto       Running  OK       ',
#  '0         KeyIso                                                  948        Manual     Running  OK       ',
#  '1077      KtmRm                                                   0          Manual     Stopped  OK       ',
#  '0         LanmanServer                                            4144       Auto       Running  OK       ',
#  '0         LanmanWorkstation                                       3092       Auto       Running  OK       ',
#  '0         lfsvc                                                   7304       Manual     Running  OK       ',
#  '0         LicenseManager                                          5872       Manual     Running  OK       ',
#  '1077      lltdsvc                                                 0          Manual     Stopped  OK       ',
#  '0         lmhosts                                                 16320      Manual     Running  OK       ',
#  '0         LMS                                                     4312       Auto       Running  OK       ',
#  '0         LSM                                                     1208       Unknown    Running  UNKNOWN  ',
#  '0         LxpSvc                                                  0          Manual     Stopped  OK       ',
#  '1077      LxssManager                                             0          Manual     Stopped  OK       ',
#  '0         MapsBroker                                              0          Auto       Stopped  OK       ',
#  '1077      MicrosoftEdgeElevationService                           0          Manual     Stopped  OK       ',
#  '1077      MixedRealityOpenXRSvc                                   0          Manual     Stopped  OK       ',
#  '0         mpssvc                                                  3076       Auto       Running  OK       ',
#  '1077      MSDTC                                                   0          Manual     Stopped  OK       ',
#  '1077      MSiSCSI                                                 0          Manual     Stopped  OK       ',
#  '1077      msiserver                                               0          Manual     Stopped  OK       ',
#  '1077      NaturalAuthentication                                   0          Manual     Stopped  OK       ',
#  '1077      NcaSvc                                                  0          Manual     Stopped  OK       ',
#  '0         NcbService                                              1584       Manual     Running  OK       ',
#  '1077      NcdAutoSetup                                            0          Manual     Stopped  OK       ',
#  '1077      Netlogon                                                0          Manual     Stopped  OK       ',
#  '1077      Netman                                                  0          Manual     Stopped  OK       ',
#  '0         netprofm                                                2808       Manual     Running  OK       ',
#  '0         NetSetupSvc                                             0          Unknown    Stopped  UNKNOWN  ',
#  '1077      NetTcpPortSharing                                       0          Disabled   Stopped  OK       ',
#  '0         NgcCtnrSvc                                              2308       Manual     Running  OK       ',
#  '0         NgcSvc                                                  5808       Manual     Running  OK       ',
#  '0         NlaSvc                                                  2384       Auto       Running  OK       ',
#  '0         nsi                                                     2036       Auto       Running  OK       ',
#  '0         nvagent                                                 2460       Manual     Running  OK       ',
#  '1077      ose64                                                   0          Manual     Stopped  OK       ',
#  '1077      p2pimsvc                                                0          Manual     Stopped  OK       ',
#  '1077      p2psvc                                                  0          Manual     Stopped  OK       ',
#  '0         PcaSvc                                                  5392       Manual     Running  OK       ',
#  '1077      perceptionsimulation                                    0          Manual     Stopped  OK       ',
#  '1077      PerfHost                                                0          Manual     Stopped  OK       ',
#  '1077      PhoneSvc                                                0          Manual     Stopped  OK       ',
#  '1077      pla                                                     0          Manual     Stopped  OK       ',
#  '0         PlugPlay                                                588        Manual     Running  OK       ',
#  '1077      PNRPAutoReg                                             0          Manual     Stopped  OK       ',
#  '1077      PNRPsvc                                                 0          Manual     Stopped  OK       ',
#  '1077      PolicyAgent                                             0          Manual     Stopped  OK       ',
#  '0         Power                                                   880        Auto       Running  OK       ',
#  '1077      PrintNotify                                             0          Manual     Stopped  OK       ',
#  '0         ProfSvc                                                 1944       Auto       Running  OK       ',
#  '0         PushToInstall                                           0          Manual     Stopped  OK       ',
#  '0         QWAVE                                                   11600      Manual     Running  OK       ',
#  '1077      RasAuto                                                 0          Manual     Stopped  OK       ',
#  '0         RasMan                                                  5056       Auto       Running  OK       ',
#  '1077      RemoteAccess                                            0          Disabled   Stopped  OK       ',
#  '1077      RemoteRegistry                                          0          Disabled   Stopped  OK       ',
#  '1077      RetailDemo                                              0          Manual     Stopped  OK       ',
#  '0         RmSvc                                                   5464       Manual     Running  OK       ',
#  '0         RpcEptMapper                                            1152       Auto       Running  OK       ',
#  '1077      RpcLocator                                              0          Manual     Stopped  OK       ',
#  '0         RpcSs                                                   1152       Auto       Running  OK       ',
#  '0         RstMwService                                            4396       Auto       Running  OK       ',
#  '0         RtkAudioUniversalService                                4404       Auto       Running  OK       ',
#  '0         RtkBtManServ                                            4420       Auto       Running  OK       ',
#  '0         SamSs                                                   948        Auto       Running  OK       ',
#  '0         SCardSvr                                                1544       Manual     Running  OK       ',
#  '0         ScDeviceEnum                                            0          Manual     Stopped  OK       ',
#  '0         Schedule                                                1728       Auto       Running  OK       ',
#  '1077      SCPolicySvc                                             0          Manual     Stopped  OK       ',
#  '1077      SDRSVC                                                  0          Manual     Stopped  OK       ',
#  '1077      seclogon                                                0          Manual     Stopped  OK       ',
#  '0         SECOMNService                                           4412       Auto       Running  OK       ',
#  '0         SecurityHealthService                                   10052      Manual     Running  OK       ',
#  '1077      SEMgrSvc                                                0          Manual     Stopped  OK       ',
#  '0         SENS                                                    2148       Auto       Running  OK       ',
#  '1077      SensorDataService                                       0          Manual     Stopped  OK       ',
#  '1077      SensorService                                           0          Manual     Stopped  OK       ',
#  '1077      SensrSvc                                                0          Manual     Stopped  OK       ',
#  '1077      SessionEnv                                              0          Manual     Stopped  OK       ',
#  '0         SgrmBroker                                              11548      Auto       Running  OK       ',
#  '0         SharedAccess                                            3364       Manual     Running  OK       ',
#  '1077      SharedRealitySvc                                        0          Manual     Stopped  OK       ',
#  '0         ShellHWDetection                                        3948       Auto       Running  OK       ',
#  '1077      shpamsvc                                                0          Disabled   Stopped  OK       ',
#  '1077      smphost                                                 0          Manual     Stopped  OK       ',
#  '0         SmsRouter                                               0          Manual     Stopped  OK       ',
#  '1077      SNMPTRAP                                                0          Manual     Stopped  OK       ',
#  '1077      spectrum                                                0          Manual     Stopped  OK       ',
#  '0         Spooler                                                 4040       Auto       Running  OK       ',
#  '0         sppsvc                                                  0          Auto       Stopped  OK       ',
#  '0         SSDPSRV                                                 1164       Manual     Running  OK       ',
#  '1077      ssh-agent                                               0          Disabled   Stopped  OK       ',
#  '0         SstpSvc                                                 4388       Manual     Running  OK       ',
#  '0         StateRepository                                         2548       Manual     Running  OK       ',
#  '1077      stisvc                                                  0          Manual     Stopped  OK       ',
#  '0         StorSvc                                                 12196      Auto       Running  OK       ',
#  '1077      svsvc                                                   0          Manual     Stopped  OK       ',
#  '0         swprv                                                   0          Manual     Stopped  OK       ',
#  '0         SynTPEnhService                                         3196       Auto       Running  OK       ',
#  '0         SysMain                                                 3232       Auto       Running  OK       ',
#  '0         SystemEventsBroker                                      880        Auto       Running  OK       ',
#  '0         TabletInputService                                      7028       Manual     Running  OK       ',
#  '1077      TapiSrv                                                 0          Manual     Stopped  OK       ',
#  '1077      TermService                                             0          Manual     Stopped  OK       ',
#  '0         Themes                                                  3244       Auto       Running  OK       ',
#  '1077      TieringEngineService                                    0          Manual     Stopped  OK       ',
#  '0         TimeBrokerSvc                                           1600       Manual     Running  OK       ',
#  '0         TokenBroker                                             6980       Manual     Running  OK       ',
#  '0         TrkWks                                                  4568       Auto       Running  OK       ',
#  '1077      TroubleshootingSvc                                      0          Manual     Stopped  OK       ',
#  '0         TrustedInstaller                                        0          Manual     Stopped  OK       ',
#  '1077      tzautoupdate                                            0          Disabled   Stopped  OK       ',
#  '1077      UmRdpService                                            0          Manual     Stopped  OK       ',
#  '1077      upnphost                                                0          Manual     Stopped  OK       ',
#  '0         UserManager                                             2076       Auto       Running  OK       ',
#  '0         UsoSvc                                                  3692       Auto       Running  OK       ',
#  '1077      VacSvc                                                  0          Manual     Stopped  OK       ',
#  '0         VaultSvc                                                948        Manual     Running  OK       ',
#  '1077      vds                                                     0          Manual     Stopped  OK       ',
#  '1077      vmcompute                                               0          Manual     Stopped  OK       ',
#  '1077      vmicguestinterface                                      0          Manual     Stopped  OK       ',
#  '1077      vmicheartbeat                                           0          Manual     Stopped  OK       ',
#  '1077      vmickvpexchange                                         0          Manual     Stopped  OK       ',
#  '1077      vmicrdv                                                 0          Manual     Stopped  OK       ',
#  '1077      vmicshutdown                                            0          Manual     Stopped  OK       ',
#  '1077      vmictimesync                                            0          Manual     Stopped  OK       ',
#  '1077      vmicvmsession                                           0          Manual     Stopped  OK       ',
#  '1077      vmicvss                                                 0          Manual     Stopped  OK       ',
#  '0         VSS                                                     0          Manual     Stopped  OK       ',
#  '0         W32Time                                                 0          Manual     Stopped  OK       ',
#  '0         WaaSMedicSvc                                            0          Manual     Stopped  OK       ',
#  '1077      WalletService                                           0          Manual     Stopped  OK       ',
#  '1077      WarpJITSvc                                              0          Manual     Stopped  OK       ',
#  '1077      wbengine                                                0          Manual     Stopped  OK       ',
#  '1077      WbioSrvc                                                0          Manual     Stopped  OK       ',
#  '0         Wcmsvc                                                  3644       Auto       Running  OK       ',
#  '1077      wcncsvc                                                 0          Manual     Stopped  OK       ',
#  '0         WdiServiceHost                                          4544       Manual     Running  OK       ',
#  '0         WdiSystemHost                                           13000      Manual     Running  OK       ',
#  '0         WdNisSvc                                                4252       Manual     Running  OK       ',
#  '1077      WebClient                                               0          Manual     Stopped  OK       ',
#  '1077      Wecsvc                                                  0          Manual     Stopped  OK       ',
#  '1077      WEPHOSTSVC                                              0          Manual     Stopped  OK       ',
#  '1077      wercplsupport                                           0          Manual     Stopped  OK       ',
#  '0         WerSvc                                                  0          Manual     Stopped  OK       ',
#  '1077      WFDSConMgrSvc                                           0          Manual     Stopped  OK       ',
#  '1077      WiaRpc                                                  0          Manual     Stopped  OK       ',
#  '0         WinDefend                                               4436       Auto       Running  OK       ',
#  '0         WinHttpAutoProxySvc                                     3792       Manual     Running  OK       ',
#  '0         Winmgmt                                                 3096       Auto       Running  OK       ',
#  '1077      WinRM                                                   0          Manual     Stopped  OK       ',
#  '0         wisvc                                                   0          Manual     Stopped  OK       ',
#  '0         WlanSvc                                                 3880       Auto       Running  OK       ',
#  '0         wlidsvc                                                 0          Manual     Stopped  OK       ',
#  '1077      wlpasvc                                                 0          Manual     Stopped  OK       ',
#  '1077      WManSvc                                                 0          Manual     Stopped  OK       ',
#  '1077      wmiApSrv                                                0          Manual     Stopped  OK       ',
#  '1077      WMPNetworkSvc                                           0          Manual     Stopped  OK       ',
#  '1077      workfolderssvc                                          0          Manual     Stopped  OK       ',
#  '1077      WpcMonSvc                                               0          Manual     Stopped  OK       ',
#  '0         WPDBusEnum                                              0          Manual     Stopped  OK       ',
#  '0         WpnService                                              4484       Auto       Running  OK       ',
#  '0         wscsvc                                                  5084       Auto       Running  OK       ',
#  '0         WSearch                                                 7440       Auto       Running  OK       ',
#  '0         wuauserv                                                0          Manual     Stopped  OK       ',
#  '1077      WwanSvc                                                 0          Manual     Stopped  OK       ',
#  '0         XblAuthManager                                          0          Manual     Stopped  OK       ',
#  '1077      XblGameSave                                             0          Manual     Stopped  OK       ',
#  '1077      XboxGipSvc                                              0          Manual     Stopped  OK       ',
#  '1077      XboxNetApiSvc                                           0          Manual     Stopped  OK       ',
#  '1077      AarSvc_953d5                                            0          Manual     Stopped  OK       ',
#  '1077      BcastDVRUserService_953d5                               0          Manual     Stopped  OK       ',
#  '0         BluetoothUserService_953d5                              6728       Manual     Running  OK       ',
#  '1077      CaptureService_953d5                                    0          Manual     Stopped  OK       ',
#  '0         cbdhsvc_953d5                                           6888       Manual     Running  OK       ',
#  '0         CDPUserSvc_953d5                                        6724       Auto       Running  OK       ',
#  '1077      ConsentUxUserSvc_953d5                                  0          Manual     Stopped  OK       ',
#  '1077      CredentialEnrollmentManagerUserSvc_953d5                0          Manual     Stopped  OK       ',
#  '1077      DeviceAssociationBrokerSvc_953d5                        0          Manual     Stopped  OK       ',
#  '1077      DevicePickerUserSvc_953d5                               0          Manual     Stopped  OK       ',
#  '1077      DevicesFlowUserSvc_953d5                                0          Manual     Stopped  OK       ',
#  '1077      LxssManagerUser_953d5                                   0          Manual     Stopped  OK       ',
#  '1077      MessagingService_953d5                                  0          Manual     Stopped  OK       ',
#  '0         OneSyncSvc_953d5                                        8532       Auto       Running  OK       ',
#  '1077      PimIndexMaintenanceSvc_953d5                            0          Manual     Stopped  OK       ',
#  '1077      PrintWorkflowUserSvc_953d5                              0          Manual     Stopped  OK       ',
#  '1077      UdkUserSvc_953d5                                        0          Manual     Stopped  OK       ',
#  '1077      UnistoreSvc_953d5                                       0          Manual     Stopped  OK       ',
#  '1077      UserDataSvc_953d5                                       0          Manual     Stopped  OK       ',
#  '0         WpnUserService_953d5                                    6784       Auto       Running  OK       ',
#  '',
#  '']

# %% [markdown]
# Next lets import pandas and get our dataframe. This first example is using the saved wmic output text file.

# %%
import pandas as pd

# Defining the separator as multiple spaces fixes the issues with the text 
# based table.
dta = pd.read_csv(filename, sep='\s{2,}', encoding="utf-16", engine = 'python')

# %% [markdown]
# A quick check of the first few lines to see what we are working with:

# %%
dta.head()
# Out:
#    ExitCode          Name  ProcessId StartMode    State Status
# 0      1077      AJRouter          0    Manual  Stopped     OK
# 1      1077           ALG          0    Manual  Stopped     OK
# 2      1077      AppIDSvc          0    Manual  Stopped     OK
# 3         0       Appinfo      10364    Manual  Running     OK
# 4      1077  AppReadiness          0    Manual  Stopped     OK

# %% [markdown]
# Let's see if we can do something similar with the list generated from the `popen` method above. We can see that each list entry corresponds to a row in the final dataframe we want.

# %%
# lets split each list entry in services
for i in range(len(services)):
    services[i] = services[i].split()

services
# Out:
# [['ExitCode', 'Name', 'ProcessId', 'StartMode', 'State', 'Status'],
#  ['1077', 'AJRouter', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'ALG', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'AppIDSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Appinfo', '10364', 'Manual', 'Running', 'OK'],
#  ['1077', 'AppReadiness', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'AppXSvc', '13228', 'Manual', 'Running', 'OK'],
#  ['1077', 'aspnet_state', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'AudioEndpointBuilder', '3292', 'Auto', 'Running', 'OK'],
#  ['0', 'Audiosrv', '3480', 'Auto', 'Running', 'OK'],
#  ['1077', 'autotimesvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'AxInstSV', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'BDESVC', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'BFE', '3076', 'Auto', 'Running', 'OK'],
#  ['0', 'BITS', '812', 'Auto', 'Running', 'OK'],
#  ['0', 'BrokerInfrastructure', '880', 'Auto', 'Running', 'OK'],
#  ['1077', 'Browser', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'BTAGService', '1436', 'Manual', 'Running', 'OK'],
#  ['0', 'BthAvctpSvc', '1484', 'Manual', 'Running', 'OK'],
#  ['0', 'bthserv', '1556', 'Manual', 'Running', 'OK'],
#  ['0', 'camsvc', '2568', 'Manual', 'Running', 'OK'],
#  ['0', 'CDPSvc', '6280', 'Auto', 'Running', 'OK'],
#  ['0', 'CertPropSvc', '1756', 'Manual', 'Running', 'OK'],
#  ['0', 'ClickToRunSvc', '4132', 'Auto', 'Running', 'OK'],
#  ['0', 'ClipSVC', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'com.docker.service', '4844', 'Auto', 'Running', 'OK'],
#  ['1077', 'COMSysApp', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'CoreMessagingRegistrar', '1848', 'Auto', 'Running', 'OK'],
#  ['0', 'cplspcon', '4104', 'Auto', 'Running', 'OK'],
#  ['0', 'CryptSvc', '2868', 'Auto', 'Running', 'OK'],
#  ['0', 'DcomLaunch', '880', 'Auto', 'Running', 'OK'],
#  ['0', 'defragsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'DeviceAssociationService', '2432', 'Manual', 'Running', 'OK'],
#  ['1077', 'DeviceInstall', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'DevQueryBroker', '8096', 'Manual', 'Running', 'OK'],
#  ['0', 'Dhcp', '2084', 'Auto', 'Running', 'OK'],
#  ['1077',
#   'diagnosticshub.standardcollector.service',
#   '0',
#   'Manual',
#   'Stopped',
#   'OK'],
#  ['1077', 'diagsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'DiagTrack', '4112', 'Auto', 'Running', 'OK'],
#  ['0', 'DispBrokerDesktopSvc', '2336', 'Auto', 'Running', 'OK'],
#  ['0', 'DisplayEnhancementService', '1820', 'Manual', 'Running', 'OK'],
#  ['1077', 'DmEnrollmentSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'dmwappushservice', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Dnscache', '3604', 'Auto', 'Running', 'OK'],
#  ['0', 'DoSvc', '11000', 'Auto', 'Running', 'OK'],
#  ['1077', 'dot3svc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'DPS', '4124', 'Auto', 'Running', 'OK'],
#  ['0', 'DsmSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'DsSvc', '7196', 'Manual', 'Running', 'OK'],
#  ['0', 'DusmSvc', '3616', 'Auto', 'Running', 'OK'],
#  ['1077', 'Eaphost', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'edgeupdate', '0', 'Auto', 'Stopped', 'OK'],
#  ['1077', 'edgeupdatem', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'EFS', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'embeddedmode', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'EntAppSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'esifsvc', '4244', 'Auto', 'Running', 'OK'],
#  ['0', 'EventLog', '1712', 'Auto', 'Running', 'OK'],
#  ['0', 'EventSystem', '1972', 'Auto', 'Running', 'OK'],
#  ['1077', 'Fax', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'fdPHost', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'FDResPub', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'fhsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'FontCache', '3312', 'Auto', 'Running', 'OK'],
#  ['0', 'FrameServer', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'GoogleChromeElevationService', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'gpsvc', '0', 'Auto', 'Stopped', 'OK'],
#  ['1077', 'GraphicsPerfSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'gupdate', '0', 'Auto', 'Stopped', 'OK'],
#  ['1077', 'gupdatem', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'HfcDisableService', '0', 'Disabled', 'Stopped', 'OK'],
#  ['1077', 'hidserv', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'hns', '3036', 'Manual', 'Running', 'OK'],
#  ['0', 'HPAppHelperCap', '2676', 'Auto', 'Running', 'OK'],
#  ['0', 'HPNetworkCap', '2696', 'Auto', 'Running', 'OK'],
#  ['0', 'HPSysInfoCap', '2688', 'Auto', 'Running', 'OK'],
#  ['0', 'HpTouchpointAnalyticsService', '2712', 'Auto', 'Running', 'OK'],
#  ['0', 'HvHost', '1424', 'Manual', 'Running', 'OK'],
#  ['1077', 'iaStorAfsService', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'icssvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'igccservice', '4192', 'Auto', 'Running', 'OK'],
#  ['0', 'igfxCUIService2.0.0.0', '2300', 'Auto', 'Running', 'OK'],
#  ['1077', 'IKEEXT', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'InstallService', '11428', 'Manual', 'Running', 'OK'],
#  ['1077',
#   'Intel(R)',
#   'Capability',
#   'Licensing',
#   'Service',
#   'TCP',
#   'IP',
#   'Interface',
#   '0',
#   'Manual',
#   'Stopped',
#   'OK'],
#  ['0',
#   'Intel(R)',
#   'TPM',
#   'Provisioning',
#   'Service',
#   '0',
#   'Auto',
#   'Stopped',
#   'OK'],
#  ['0', 'iphlpsvc', '4228', 'Auto', 'Running', 'OK'],
#  ['1077', 'IpxlatCfgSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'jhi_service', '4476', 'Auto', 'Running', 'OK'],
#  ['0', 'KeyIso', '948', 'Manual', 'Running', 'OK'],
#  ['1077', 'KtmRm', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'LanmanServer', '4144', 'Auto', 'Running', 'OK'],
#  ['0', 'LanmanWorkstation', '3092', 'Auto', 'Running', 'OK'],
#  ['0', 'lfsvc', '7304', 'Manual', 'Running', 'OK'],
#  ['0', 'LicenseManager', '5872', 'Manual', 'Running', 'OK'],
#  ['1077', 'lltdsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'lmhosts', '16320', 'Manual', 'Running', 'OK'],
#  ['0', 'LMS', '4312', 'Auto', 'Running', 'OK'],
#  ['0', 'LSM', '1208', 'Unknown', 'Running', 'UNKNOWN'],
#  ['0', 'LxpSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'LxssManager', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'MapsBroker', '0', 'Auto', 'Stopped', 'OK'],
#  ['1077', 'MicrosoftEdgeElevationService', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'MixedRealityOpenXRSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'mpssvc', '3076', 'Auto', 'Running', 'OK'],
#  ['1077', 'MSDTC', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'MSiSCSI', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'msiserver', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'NaturalAuthentication', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'NcaSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'NcbService', '1584', 'Manual', 'Running', 'OK'],
#  ['1077', 'NcdAutoSetup', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'Netlogon', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'Netman', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'netprofm', '2808', 'Manual', 'Running', 'OK'],
#  ['0', 'NetSetupSvc', '0', 'Unknown', 'Stopped', 'UNKNOWN'],
#  ['1077', 'NetTcpPortSharing', '0', 'Disabled', 'Stopped', 'OK'],
#  ['0', 'NgcCtnrSvc', '2308', 'Manual', 'Running', 'OK'],
#  ['0', 'NgcSvc', '5808', 'Manual', 'Running', 'OK'],
#  ['0', 'NlaSvc', '2384', 'Auto', 'Running', 'OK'],
#  ['0', 'nsi', '2036', 'Auto', 'Running', 'OK'],
#  ['0', 'nvagent', '2460', 'Manual', 'Running', 'OK'],
#  ['1077', 'ose64', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'p2pimsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'p2psvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'PcaSvc', '5392', 'Manual', 'Running', 'OK'],
#  ['1077', 'perceptionsimulation', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'PerfHost', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'PhoneSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'pla', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'PlugPlay', '588', 'Manual', 'Running', 'OK'],
#  ['1077', 'PNRPAutoReg', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'PNRPsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'PolicyAgent', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Power', '880', 'Auto', 'Running', 'OK'],
#  ['1077', 'PrintNotify', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'ProfSvc', '1944', 'Auto', 'Running', 'OK'],
#  ['0', 'PushToInstall', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'QWAVE', '11600', 'Manual', 'Running', 'OK'],
#  ['1077', 'RasAuto', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'RasMan', '5056', 'Auto', 'Running', 'OK'],
#  ['1077', 'RemoteAccess', '0', 'Disabled', 'Stopped', 'OK'],
#  ['1077', 'RemoteRegistry', '0', 'Disabled', 'Stopped', 'OK'],
#  ['1077', 'RetailDemo', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'RmSvc', '5464', 'Manual', 'Running', 'OK'],
#  ['0', 'RpcEptMapper', '1152', 'Auto', 'Running', 'OK'],
#  ['1077', 'RpcLocator', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'RpcSs', '1152', 'Auto', 'Running', 'OK'],
#  ['0', 'RstMwService', '4396', 'Auto', 'Running', 'OK'],
#  ['0', 'RtkAudioUniversalService', '4404', 'Auto', 'Running', 'OK'],
#  ['0', 'RtkBtManServ', '4420', 'Auto', 'Running', 'OK'],
#  ['0', 'SamSs', '948', 'Auto', 'Running', 'OK'],
#  ['0', 'SCardSvr', '1544', 'Manual', 'Running', 'OK'],
#  ['0', 'ScDeviceEnum', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Schedule', '1728', 'Auto', 'Running', 'OK'],
#  ['1077', 'SCPolicySvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'SDRSVC', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'seclogon', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'SECOMNService', '4412', 'Auto', 'Running', 'OK'],
#  ['0', 'SecurityHealthService', '10052', 'Manual', 'Running', 'OK'],
#  ['1077', 'SEMgrSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'SENS', '2148', 'Auto', 'Running', 'OK'],
#  ['1077', 'SensorDataService', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'SensorService', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'SensrSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'SessionEnv', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'SgrmBroker', '11548', 'Auto', 'Running', 'OK'],
#  ['0', 'SharedAccess', '3364', 'Manual', 'Running', 'OK'],
#  ['1077', 'SharedRealitySvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'ShellHWDetection', '3948', 'Auto', 'Running', 'OK'],
#  ['1077', 'shpamsvc', '0', 'Disabled', 'Stopped', 'OK'],
#  ['1077', 'smphost', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'SmsRouter', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'SNMPTRAP', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'spectrum', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Spooler', '4040', 'Auto', 'Running', 'OK'],
#  ['0', 'sppsvc', '0', 'Auto', 'Stopped', 'OK'],
#  ['0', 'SSDPSRV', '1164', 'Manual', 'Running', 'OK'],
#  ['1077', 'ssh-agent', '0', 'Disabled', 'Stopped', 'OK'],
#  ['0', 'SstpSvc', '4388', 'Manual', 'Running', 'OK'],
#  ['0', 'StateRepository', '2548', 'Manual', 'Running', 'OK'],
#  ['1077', 'stisvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'StorSvc', '12196', 'Auto', 'Running', 'OK'],
#  ['1077', 'svsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'swprv', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'SynTPEnhService', '3196', 'Auto', 'Running', 'OK'],
#  ['0', 'SysMain', '3232', 'Auto', 'Running', 'OK'],
#  ['0', 'SystemEventsBroker', '880', 'Auto', 'Running', 'OK'],
#  ['0', 'TabletInputService', '7028', 'Manual', 'Running', 'OK'],
#  ['1077', 'TapiSrv', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'TermService', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Themes', '3244', 'Auto', 'Running', 'OK'],
#  ['1077', 'TieringEngineService', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'TimeBrokerSvc', '1600', 'Manual', 'Running', 'OK'],
#  ['0', 'TokenBroker', '6980', 'Manual', 'Running', 'OK'],
#  ['0', 'TrkWks', '4568', 'Auto', 'Running', 'OK'],
#  ['1077', 'TroubleshootingSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'TrustedInstaller', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'tzautoupdate', '0', 'Disabled', 'Stopped', 'OK'],
#  ['1077', 'UmRdpService', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'upnphost', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'UserManager', '2076', 'Auto', 'Running', 'OK'],
#  ['0', 'UsoSvc', '3692', 'Auto', 'Running', 'OK'],
#  ['1077', 'VacSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'VaultSvc', '948', 'Manual', 'Running', 'OK'],
#  ['1077', 'vds', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmcompute', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmicguestinterface', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmicheartbeat', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmickvpexchange', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmicrdv', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmicshutdown', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmictimesync', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmicvmsession', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'vmicvss', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'VSS', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'W32Time', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WaaSMedicSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WalletService', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WarpJITSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'wbengine', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WbioSrvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'Wcmsvc', '3644', 'Auto', 'Running', 'OK'],
#  ['1077', 'wcncsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WdiServiceHost', '4544', 'Manual', 'Running', 'OK'],
#  ['0', 'WdiSystemHost', '13000', 'Manual', 'Running', 'OK'],
#  ['0', 'WdNisSvc', '4252', 'Manual', 'Running', 'OK'],
#  ['1077', 'WebClient', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'Wecsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WEPHOSTSVC', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'wercplsupport', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WerSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WFDSConMgrSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WiaRpc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WinDefend', '4436', 'Auto', 'Running', 'OK'],
#  ['0', 'WinHttpAutoProxySvc', '3792', 'Manual', 'Running', 'OK'],
#  ['0', 'Winmgmt', '3096', 'Auto', 'Running', 'OK'],
#  ['1077', 'WinRM', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'wisvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WlanSvc', '3880', 'Auto', 'Running', 'OK'],
#  ['0', 'wlidsvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'wlpasvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WManSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'wmiApSrv', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WMPNetworkSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'workfolderssvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WpcMonSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WPDBusEnum', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WpnService', '4484', 'Auto', 'Running', 'OK'],
#  ['0', 'wscsvc', '5084', 'Auto', 'Running', 'OK'],
#  ['0', 'WSearch', '7440', 'Auto', 'Running', 'OK'],
#  ['0', 'wuauserv', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'WwanSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'XblAuthManager', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'XblGameSave', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'XboxGipSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'XboxNetApiSvc', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'AarSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'BcastDVRUserService_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'BluetoothUserService_953d5', '6728', 'Manual', 'Running', 'OK'],
#  ['1077', 'CaptureService_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'cbdhsvc_953d5', '6888', 'Manual', 'Running', 'OK'],
#  ['0', 'CDPUserSvc_953d5', '6724', 'Auto', 'Running', 'OK'],
#  ['1077', 'ConsentUxUserSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077',
#   'CredentialEnrollmentManagerUserSvc_953d5',
#   '0',
#   'Manual',
#   'Stopped',
#   'OK'],
#  ['1077', 'DeviceAssociationBrokerSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'DevicePickerUserSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'DevicesFlowUserSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'LxssManagerUser_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'MessagingService_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'OneSyncSvc_953d5', '8532', 'Auto', 'Running', 'OK'],
#  ['1077', 'PimIndexMaintenanceSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'PrintWorkflowUserSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'UdkUserSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'UnistoreSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['1077', 'UserDataSvc_953d5', '0', 'Manual', 'Stopped', 'OK'],
#  ['0', 'WpnUserService_953d5', '6784', 'Auto', 'Running', 'OK'],
#  [],
#  []]

# %%
data = pd.DataFrame(services)

data.head()
# Out:
#           0         1          2          3        4       5     6     7  \
# 0  ExitCode      Name  ProcessId  StartMode    State  Status  None  None
# 1      1077  AJRouter          0     Manual  Stopped      OK  None  None
# 2      1077       ALG          0     Manual  Stopped      OK  None  None
# 3      1077  AppIDSvc          0     Manual  Stopped      OK  None  None
# 4         0   Appinfo      10364     Manual  Running      OK  None  None
#
#       8     9    10    11
# 0  None  None  None  None
# 1  None  None  None  None
# 2  None  None  None  None
# 3  None  None  None  None
# 4  None  None  None  None

# %%
# first we'll drop the extra columns and any rows with no data

data = data.drop(axis=1, columns = range(6,12)).dropna()

data
# Out:
#             0                           1          2          3        4  \
# 0    ExitCode                        Name  ProcessId  StartMode    State
# 1        1077                    AJRouter          0     Manual  Stopped
# 2        1077                         ALG          0     Manual  Stopped
# 3        1077                    AppIDSvc          0     Manual  Stopped
# 4           0                     Appinfo      10364     Manual  Running
# ..        ...                         ...        ...        ...      ...
# 272      1077  PrintWorkflowUserSvc_953d5          0     Manual  Stopped
# 273      1077            UdkUserSvc_953d5          0     Manual  Stopped
# 274      1077           UnistoreSvc_953d5          0     Manual  Stopped
# 275      1077           UserDataSvc_953d5          0     Manual  Stopped
# 276         0        WpnUserService_953d5       6784       Auto  Running
#
#           5
# 0    Status
# 1        OK
# 2        OK
# 3        OK
# 4        OK
# ..      ...
# 272      OK
# 273      OK
# 274      OK
# 275      OK
# 276      OK
#
# [277 rows x 6 columns]

# %%
columns = data.iloc[0]
data = data[1:]
data.columns = columns

data
# Out:
# 0     ExitCode
# 1         Name
# 2    ProcessId
# 3    StartMode
# 4        State
# 5       Status
# Name: 0, dtype: object
# 0   ExitCode                        Name ProcessId StartMode    State Status
# 1       1077                    AJRouter         0    Manual  Stopped     OK
# 2       1077                         ALG         0    Manual  Stopped     OK
# 3       1077                    AppIDSvc         0    Manual  Stopped     OK
# 4          0                     Appinfo     10364    Manual  Running     OK
# 5       1077                AppReadiness         0    Manual  Stopped     OK
# ..       ...                         ...       ...       ...      ...    ...
# 272     1077  PrintWorkflowUserSvc_953d5         0    Manual  Stopped     OK
# 273     1077            UdkUserSvc_953d5         0    Manual  Stopped     OK
# 274     1077           UnistoreSvc_953d5         0    Manual  Stopped     OK
# 275     1077           UserDataSvc_953d5         0    Manual  Stopped     OK
# 276        0        WpnUserService_953d5      6784      Auto  Running     OK
#
# [276 rows x 6 columns]

# %% [markdown]
# Now lets take a look at some basic stats on the dataframe. Remember that by default, the `describe()` method will only show stats for numerical fields. To show stats for categorical data, we can use this little loop:

# %%
for col in dta.columns:
    dta[col].describe()

# %% [markdown]
# **Note:** If that didn't work, run the following cell and then re-run the last one. Notebooks do not display multiple outputs by default.

# %%
from IPython.core.interactiveshell import InteractiveShell

# pretty print all cell's output and not just the last one
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# If we are potentially going to compare this output over time or against other machines or a baseline, lets add the hostname and a time stamp to our records. To have a clean and usable dataframe, it is important that each record contains all of the pertinent information. If we want to compare the time of day the a process is running against which hosts are running the process, then each individual process record must contain all of that information.
#
# The next line uses the native Windows commandline to get the hostname. For most applications, this will not be viable, since the data should come from mission-related systems and not from the host running the notebook server. You could potentially get the hostname from as asset inventory, file naming convention, etc.

# %%
import os

hostname = os.popen('hostname').read().strip()
hostname
# Out:
# 'LAPTOP-06RQRGUU'

# %% [markdown]
# Now we can use the insert method to add our hostname column. The first argument is the index for the new column. Next we have the column heading. Finally, we add the hostname string we grabbed in the last cell.

# %%
dta.insert(0, 'Hostname', hostname)
dta.head()
# Out:
#           Hostname  ExitCode          Name  ProcessId StartMode    State  \
# 0  LAPTOP-06RQRGUU      1077      AJRouter          0    Manual  Stopped
# 1  LAPTOP-06RQRGUU      1077           ALG          0    Manual  Stopped
# 2  LAPTOP-06RQRGUU      1077      AppIDSvc          0    Manual  Stopped
# 3  LAPTOP-06RQRGUU         0       Appinfo      10364    Manual  Running
# 4  LAPTOP-06RQRGUU      1077  AppReadiness          0    Manual  Stopped
#
#   Status
# 0     OK
# 1     OK
# 2     OK
# 3     OK
# 4     OK

# %% [markdown]
# One last useful bit of information is a time stamp. Pandas has a native datatype of Timestamp we can use, along with the system time for this example.
#
# First let's take a look at what datetime can provide.

# %%
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%m/%d/%Y %H:%M:%S")
dt_string
# Out:
# '11/21/2020 13:14:00'

# %% [markdown]
# Now lets insert that datetime into our DataFrame:

# %%
time = pd.Timestamp(now)

dta.insert(0, "Time", time)
dta.head()
# Out:
#                         Time  ExitCode          Name  ProcessId StartMode  \
# 0 2020-11-21 13:14:00.167826      1077      AJRouter          0    Manual
# 1 2020-11-21 13:14:00.167826      1077           ALG          0    Manual
# 2 2020-11-21 13:14:00.167826      1077      AppIDSvc          0    Manual
# 3 2020-11-21 13:14:00.167826         0       Appinfo      10364    Manual
# 4 2020-11-21 13:14:00.167826      1077  AppReadiness          0    Manual
#
#      State Status
# 0  Stopped     OK
# 1  Stopped     OK
# 2  Stopped     OK
# 3  Running     OK
# 4  Stopped     OK

# %% [markdown]
# With data like this, we can now combine this dataframe with other ones collected independently and look for insights across them all.

# %%
dta.dtypes
# Out:
# Time         datetime64[ns]
# ExitCode              int64
# Name                 object
# ProcessId             int64
# StartMode            object
# State                object
# Status               object
# dtype: object
